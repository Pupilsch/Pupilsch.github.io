# %%
import pandas as pd
import bqplot
import numpy as np
import traitlets
import ipywidgets
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
buildings = pd.read_csv("building_inventory.csv", na_values = {'Year Acquired' :0, 'Year Constructed':0, 'Square footage':0})

# %%
buildings
# Out:
#                            Agency Name  \
# 0      Department of Natural Resources
# 1      Department of Natural Resources
# 2      Department of Natural Resources
# 3      Department of Natural Resources
# 4      Department of Natural Resources
# ...                                ...
# 8857      Department of Transportation
# 8858      Department of Transportation
# 8859      Department of Transportation
# 8860  Illinois Community College Board
# 8861    Department of Military Affairs
#
#                                           Location Name  \
# 0       Anderson Lake Conservation Area - Fulton County
# 1       Anderson Lake Conservation Area - Fulton County
# 2       Anderson Lake Conservation Area - Fulton County
# 3       Anderson Lake Conservation Area - Fulton County
# 4       Anderson Lake Conservation Area - Fulton County
# ...                                                 ...
# 8857  Belvidere Maintenance Storage Facility - Boone...
# ...

# %%
buildings_data = pd.pivot_table(buildings, index = ['Congress Dist'], values = ['Square Footage'], columns = ['Agency Name'], aggfunc = np.sum)

# %%
buildings_data_log = np.log10(buildings_data)

# %%
buildings_data_log
# Out:
#                                 Square Footage  \
# Agency Name   Appellate Court / Fifth District
# Congress Dist
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                    4.179667
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# ...

# %%
mySelectedLabel = ipywidgets.Label("Square footage in log 10")

# %%
i, j = 0, 0
def on_selected(change): # already modified for our 3d data
    if len(change['owner'].selected) == 1:
        i, j = change['owner'].selected[0]
        v = buildings_data_log.iat[i,j] # this is a 2d array!!
        mySelectedLabel.value = 'Weighted square footage = ' + str(v)
        ##### Add in what changes for our histogram
        ####hist.sample = data3d[i,j]
# make sure we are observing for changes in our heatmap

# %%
# 2. Scales
col_sc = bqplot.ColorScale(scheme="Yellow") 
x_sc = bqplot.LinearScale() # numerical, long
y_sc = bqplot.LinearScale() # numerical, lat

# %%
ax_col = bqplot.ColorAxis(scale = col_sc, orientation='vertical', side='right') 
ax_x = bqplot.Axis(scale = x_sc, label='Agency Name') # same x/y ax we had before
ax_y = bqplot.Axis(scale = y_sc, orientation='vertical', label='ConGress Dist')

# %%
heat_map = bqplot.GridHeatMap(color = buildings_data_log, 
                              scales = {'color':col_sc, 'row':y_sc, 'column':x_sc},
                             interactions={'click':'select'},
                             anchor_style={'fill':'blue'},
                             selected_style={'opacity':1.0},
                             unselected_style={'opacity':0.8})

# %%
heat_map.observe(on_selected, 'selected')

# %%
fig = bqplot.Figure(marks=[heat_map], axes=[ax_col, ax_y, ax_x])

# %%
def get_year(i, j):
    year=[]
    for index, row in buildings.iterrows():
        if row['Congress Dist'] == dist and row['Agency Name'] == Agency:
            if  row['Year Acquired'] > 1000 and row['Square Footage']> 1:
                year.append(row['Year Acquired'])
    year = np.array(year)
    np.sort(year)
    year = np.unique(year)
    return year

# %%
def get_footage(i, j):
    year=[]
    for index, row in buildings.iterrows():
        if row['Congress Dist'] == dist and row['Agency Name'] == Agency:
            if  row['Year Acquired'] > 1000 and row['Square Footage']> 1:
                year.append(row['Year Acquired'])
    year = np.array(year)
    np.sort(year)
    year = np.unique(year)
    footage = np.zeros(len(year))
    for index, row in buildings.iterrows():
        if row['Congress Dist'] == dist and row['Agency Name'] == Agency:
            if  row['Year Acquired'] > 1000 and row['Square Footage']> 1:
                footage[np.where(year == row['Year Acquired'])] = footage[np.where(year == row['Year Acquired'])] + row['Square Footage']
    footage = np.log10(footage)
    return footage

# %% [markdown]
# Next we add the line plot:

# %%
x_sch = bqplot.LinearScale()
y_sch = bqplot.LinearScale()

# 3. Axis -- x & y
ax_xh = bqplot.Axis(scale=x_sch, label='Year') # binning into here
ax_yh = bqplot.Axis(scale=y_sch, orientation='vertical', label='log Square foot acquired')

i, j = 0,0 # to start, this is hardcoded

lines = bqplot.Lines(x=get_year(i,j), y=get_footage(i,j), scales={'x': x_sch, 'y': y_sch})

figh = bqplot.Figure(marks=[lines], axes=[ax_xh, ax_yh])
figh
# Out:
# Figure(axes=[Axis(label='Year', scale=LinearScale()), Axis(label='log Square foot acquired', orientation='vert…

# %%
fig.layout.min_width='500px'
figh.layout.min_width='500px'

figures = ipywidgets.HBox([fig, figh]) # figures side-by-side

# label on top
myDashboard = ipywidgets.VBox([mySelectedLabel, figures])
myDashboard
